# %%
from sp_ubt_gettransamountdetails_copy import *


from logger_util import get_logger
sp_name = "SP_GETRTSHOPCLOUD"
etl_name = "UBTI_3.0.2_TR_RTMS_SAPFIN_SHOP"
logger = get_logger(sp_name)
df = sp_ubt_gettransamountdetails('20250625', '20250625',logger)
# Out:
# 2026-01-11 12:51:48,400 [INFO] [ETL:SP_GETRTSHOPCLOUD] [SP_GETTRANSAMOUNTDETAILS] Initializing SP_UBT_GETTRANSAMOUNTDETAILS with input range from=20250625, to=20250625
# 2026-01-11 12:51:52,478 [INFO] [ETL:SP_GETRTSHOPCLOUD] [SP_GETTRANSAMOUNTDETAILS] Calling SP_UBT_GETCOMMONUBTDATES ...
# 2026-01-11 12:51:52,483 [INFO] [ETL:SP_GETRTSHOPCLOUD] [SP_GETCOMMONUBTDATES] Initializing SP_UBT_GETCOMMONUBTDATES with input range from=20250625, to=20250625
# 2026-01-11 12:51:57,325 [INFO] [ETL:SP_GETRTSHOPCLOUD] [SP_GETCOMMONUBTDATES] Retrieving BMCS/IGT/OB host ...
# 2026-01-11 12:51:57,330 [DEBUG] [ETL:SP_GETRTSHOPCLOUD] [SP_GETCOMMONUBTDATES] Querying perioddatetime for BMCS, date=2025-06-24 00:00:00
# 2026-01-11 12:51:58,222 [DEBUG] [ETL:SP_GETRTSHOPCLOUD] [SP_GETCOMMONUBTDATES] Querying perioddatetime for BMCS, date=2025-06-25 00:00:00
# 2026-01-11 12:51:58,822 [DEBUG] [ETL:SP_GETRTSHOPCLOUD] [SP_GETCOMMONUBTDATES] Querying perioddatetime for IGT, date=2025-06-24 00:00:00
# ...

# %%
df[(df['PRODNAME'] == 'HORSE RACING') & (df['FLAG'] == 'COL') & (df['AMOUNT']!=0)]
# Out:
#     TERDISPLAYID      PRODNAME FLAG    AMOUNT  TICKETCOUNT ACTUALDATE  \
# 570    151189001  HORSE RACING  COL  208920.0           77        NaN
#
#      LOCTYPEID TRANSTYPE
# 570        1.0        CH

# %%
df.to_csv('sp_ubt_gettransamountdetails_output.csv', index=False)
